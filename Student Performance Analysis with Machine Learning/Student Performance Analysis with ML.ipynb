# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
# for visualizations
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# !pip install dabl
import dabl
# Out:
# Requirement already satisfied: dabl in c:\users\serkan\appdata\local\programs\python\python310\lib\site-packages (0.2.2)
# Requirement already satisfied: seaborn in c:\users\serkan\appdata\local\programs\python\python310\lib\site-packages (from dabl) (0.11.2)
# Requirement already satisfied: numpy in c:\users\serkan\appdata\local\programs\python\python310\lib\site-packages (from dabl) (1.22.1)
# Requirement already satisfied: scipy in c:\users\serkan\appdata\local\programs\python\python310\lib\site-packages (from dabl) (1.8.0)
# Requirement already satisfied: matplotlib in c:\users\serkan\appdata\local\programs\python\python310\lib\site-packages (from dabl) (3.5.1)
# Requirement already satisfied: scikit-learn>=0.24.0 in c:\users\serkan\appdata\local\programs\python\python310\lib\site-packages (from dabl) (1.0.2)
# Requirement already satisfied: pandas in c:\users\serkan\appdata\local\programs\python\python310\lib\site-packages (from dabl) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\serkan\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn>=0.24.0->dabl) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\serkan\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn>=0.24.0->dabl) (1.1.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\serkan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->dabl) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\serkan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->dabl) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\serkan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->dabl) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\serkan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->dabl) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\serkan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->dabl) (3.0.7)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\serkan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->dabl) (9.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\serkan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->dabl) (4.29.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\serkan\appdata\local\programs\python\python310\lib\site-packages (from pandas->dabl) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\serkan\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib->dabl) (1.16.0)
# WARNING: You are using pip version 21.3.1; however, version 22.2.2 is available.
# You should consider upgrading via the 'C:\Users\SERKAN\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
data = pd.read_csv('StudentsPerformance.csv')

# %%
print(data.shape)
# Out:
# (1000, 8)

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# ### Lets check the no. of unique items present in the categorical column
#
# ### Hayır'ı kontrol edelim. kategorik sütunda bulunan benzersiz öğelerin sayısı

# %%
data.select_dtypes('object').nunique()
# Out:
# gender                         2
# race/ethnicity                 5
# parental level of education    6
# lunch                          2
# test preparation course        2
# dtype: int64

# %% [markdown]
# ### lets check the percentage of missing data in each columns present in the data :
#
# ### verilerde bulunan her sütundaki eksik verilerin yüzdesini kontrol etmenizi sağlar:

# %%
no_of_columns = data.shape[0]

# %%
percentage_of_missing_data = data.isnull().sum()/no_of_columns

# %%
print(percentage_of_missing_data)
# Out:
# gender                         0.0
# race/ethnicity                 0.0
# parental level of education    0.0
# lunch                          0.0
# test preparation course        0.0
# math score                     0.0
# reading score                  0.0
# writing score                  0.0
# dtype: float64

# %% [markdown]
# ### To see comparison of all other attributes with respect to Math Marks
#
# ### Matematik İşaretlerine göre diğer tüm özelliklerin karşılaştırmasını görmek için

# %%
plt.rcParams['figure.figsize'] = (18, 6)
plt.style.use('fivethirtyeight')
dabl.plot(data, target_col = 'math score')
# Out:
# Target looks like regression
# [array([[<AxesSubplot:title={'center':'F=2.01E+03'}, xlabel='reading score', ylabel='math score'>,
#          <AxesSubplot:title={'center':'F=1.81E+03'}, xlabel='writing score'>]],
#        dtype=object),
#  array([[<AxesSubplot:title={'center':'F=8.13E-02'}, xlabel='math score', ylabel='gender'>,
#          <AxesSubplot:title={'center':'F=3.06E-02'}, xlabel='math score', ylabel='race/ethnicity'>,
#          <AxesSubplot:title={'center':'F=1.96E-04'}, xlabel='math score', ylabel='parental level of...'>,
#          <AxesSubplot:title={'center':'F=0.00E+00'}, xlabel='math score', ylabel='lunch'>,
#          <AxesSubplot:title={'center':'F=0.00E+00'}, xlabel='math score', ylabel='test preparation ...'>]],
#        dtype=object)]

# %% [markdown]
# ### Comparison of all other attributes with respect to Reading Marks :
#
# ### Okuma İşaretlerine göre diğer tüm özelliklerin karşılaştırılması:

# %%
plt.rcParams['figure.figsize'] = (18, 6)
plt.style.use('fivethirtyeight')
dabl.plot(data, target_col = 'reading score')
# Out:
# Target looks like regression
# [array([[<AxesSubplot:title={'center':'F=1.02E+04'}, xlabel='writing score', ylabel='reading score'>,
#          <AxesSubplot:title={'center':'F=2.01E+03'}, xlabel='math score'>]],
#        dtype=object),
#  array([[<AxesSubplot:title={'center':'F=4.26E-02'}, xlabel='reading score', ylabel='gender'>,
#          <AxesSubplot:title={'center':'F=2.95E-02'}, xlabel='reading score', ylabel='race/ethnicity'>,
#          <AxesSubplot:title={'center':'F=1.92E-02'}, xlabel='reading score', ylabel='parental level of...'>,
#          <AxesSubplot:title={'center':'F=8.73E-03'}, xlabel='reading score', ylabel='lunch'>,
#          <AxesSubplot:title={'center':'F=0.00E+00'}, xlabel='reading score', ylabel='test preparation ...'>]],
#        dtype=object)]

# %% [markdown]
# ### Lets check the Effect of Lunch on Student’s Performnce
#
# ### Öğle Yemeğinin Öğrenci Performansı Üzerindeki Etkisini Kontrol Edelim

# %%
data[['lunch','gender','math score','writing score',
      'reading score']].groupby(['lunch','gender']).agg('median')
# Out:
#                      math score  writing score  reading score
# lunch        gender
# free/reduced female        57.0           68.0           67.0
#              male          62.0           59.0           61.0
# standard     female        67.0           76.0           75.0
#              male          72.0           67.0           67.5

# %% [markdown]
# ### Lets check the Effect of Test Preparation Course on Scores
#
# ### Test Hazırlık Kursunun Puanlar Üzerindeki Etkisini Kontrol Edelim

# %%
data[['test preparation course',
      'gender',
      'math score',
      'writing score',
      'reading score']].groupby(['test preparation course','gender']).agg('median')
# Out:
#                                 math score  writing score  reading score
# test preparation course gender
# completed               female        67.0           79.0           78.0
#                         male          73.0           70.0           71.0
# none                    female        62.0           70.0           71.0
#                         male          67.0           60.0           63.0

# %% [markdown]
# # Data Visualizations

# %% [markdown]
# ### Visualizing the number of male and female in the data set
#
# ### Veri kümesindeki kadın ve erkek sayısını görselleştirme

# %%
plt.rcParams['figure.figsize'] = (15, 5)
sns.countplot(data['gender'], palette = 'bone')
plt.title('Comparison of Males and Females', fontweight = 30)
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Visualizing the different groups in the data set
#
# ### Veri kümesindeki farklı grupları görselleştirme

# %%
plt.rcParams['figure.figsize'] = (15, 9)
plt.style.use('ggplot')

sns.countplot(data['race/ethnicity'], palette = 'pink')
plt.title('Comparison of various groups', fontweight = 30, fontsize = 20)
plt.xlabel('Groups')
plt.ylabel('count')
plt.show()

# %% [markdown]
# ### Visualizing the different parental education levels
#
# ### Farklı ebeveyn eğitim düzeylerini görselleştirme

# %%
plt.rcParams['figure.figsize'] = (15, 9)
plt.style.use('fivethirtyeight')

sns.countplot(data['parental level of education'], palette = 'Blues')
plt.title('Comparison of Parental Education', fontweight = 30, fontsize = 20)
plt.xlabel('Degree')
plt.ylabel('count')
plt.show()

# %% [markdown]
# ### Visualizing Maths score
#
# ### Matematik puanını görselleştirme

# %%
plt.rcParams['figure.figsize'] = (15, 9)
plt.style.use('tableau-colorblind10')

sns.countplot(data['math score'], palette = 'BuPu')
plt.title('Comparison of math scores', fontweight = 30, fontsize = 20)
plt.xlabel('score')
plt.ylabel('count')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ### Computing the total score for each student
#
# ### Her öğrenci için toplam puanın hesaplanması

# %%
data['total_score'] = data['math score'] + data['reading score'] + data['writing score']

sns.distplot(data['total_score'], color = 'magenta')

plt.title('comparison of total score of all the students', fontweight = 30, fontsize = 20)
plt.xlabel('total score scored by the students')
plt.ylabel('count')
plt.show()

# %% [markdown]
# ### Computing percentage for each of the students
#
# ### Her öğrenci için hesaplama yüzdesi

# %%
# importing math library to use ceil
from math import * 
import warnings
warnings.filterwarnings('ignore')

data['percentage'] = data['total_score']/3

for i in range(0, 1000):
    data['percentage'][i] = ceil(data['percentage'][i])

plt.rcParams['figure.figsize'] = (15, 9)
sns.distplot(data['percentage'], color = 'orange')

plt.title('Comparison of percentage scored by all the students', fontweight = 30, fontsize = 20)
plt.xlabel('Percentage scored')
plt.ylabel('Count')
plt.show()
