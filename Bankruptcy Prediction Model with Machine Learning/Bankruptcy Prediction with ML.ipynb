# %% [markdown]
# ### Bankruptcy is a state of insolvency when a business or legal person cannot repay debts to creditors. Bankruptcy is primarily imposed by court order when initiated by the debtor. In this article, I will walk you through how to train a bankruptcy prediction model with machine learning using Python.
#
# ### İflas, bir ticari veya tüzel kişinin alacaklılara olan borçlarını ödeyemediği bir iflas durumudur. İflas, borçlu tarafından başlatıldığında öncelikle mahkeme kararıyla verilir. Bu yazıda, Python kullanarak makine öğrenimi ile bir iflas tahmin modelinin nasıl eğitileceği konusunda size yol göstereceğim.

# %% [markdown]
# # Bankruptcy Prediction Model with Machine Learning

# %% [markdown]
# ### Bankruptcy is the concept of financial accounts. If you are one of the data science enthusiasts who started with data science after commerce then you should be aware of what bankruptcy is. When a business or legal person fails to pay the debts of creditors and becomes insolvent at some point, this type of situation is called bankruptcy.
#
# ### By using machine learning algorithms we can train a model to predict whether a company or a legal person will become bankrupt in future or not. In the section below, I will take you through a machine learning tutorial on how to train a model for the task of bankruptcy prediction of a company by using the Python programming language.
#
# ### İflas, finansal hesaplar kavramıdır. Ticaretten sonra veri bilimi ile başlayan veri bilimi meraklılarından biriyseniz, iflasın ne olduğunu bilmelisiniz. Bir işletme veya tüzel kişinin alacaklıların borçlarını ödeyememesi ve bir noktada iflas etmesi durumunda bu tür bir duruma iflas denir.
#
# ### Makine öğrenimi algoritmalarını kullanarak bir şirketin veya bir tüzel kişinin gelecekte iflas edip etmeyeceğini tahmin etmek için bir model eğitebiliriz. Aşağıdaki bölümde, Python programlama dilini kullanarak bir şirketin iflas tahmini görevi için bir modelin nasıl eğitileceğine dair bir makine öğrenimi eğitimine götüreceğim.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv("bank.csv")

# %%
data.head()
# Out:
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0          1                                           0.370594
# 1          1                                           0.464291
# 2          1                                           0.426071
# 3          1                                           0.399844
# 4          1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# 4                                           0.522298
#
#     Operating Gross Margin   Realized Sales Gross Margin  \
# 0                 0.601457                      0.601457
# 1                 0.610235                      0.610235
# 2                 0.601450                      0.601364
# 3                 0.583541                      0.583541
# 4                 0.598783                      0.598783
#
#     Operating Profit Rate   Pre-tax net Interest Rate  \
# 0                0.998969                    0.796887
# 1                0.998946                    0.797380
# 2                0.998857                    0.796403
# 3                0.998700                    0.796967
# 4                0.998973                    0.797366
#
#     After-tax net Interest Rate   Non-industry income and expenditure/revenue  \
# 0                      0.808809                                      0.302646
# 1                      0.809301                                      0.303556
# 2                      0.808388                                      0.302035
# 3                      0.808966                                      0.303350
# 4                      0.809304                                      0.303475
#
#    ...   Net Income to Total Assets   Total assets to GNP price  \
# 0  ...                     0.716845                    0.009219
# 1  ...                     0.795297                    0.008323
# 2  ...                     0.774670                    0.040003
# 3  ...                     0.739555                    0.003252
# 4  ...                     0.795016                    0.003878
#
#     No-credit Interval   Gross Profit to Sales  \
# 0             0.622879                0.601453
# 1             0.623652                0.610237
# 2             0.623841                0.601449
# 3             0.622929                0.583538
# 4             0.623521                0.598782
#
#     Net Income to Stockholder's Equity   Liability to Equity  \
# 0                             0.827890              0.290202
# 1                             0.839969              0.283846
# 2                             0.836774              0.290189
# 3                             0.834697              0.281721
# 4                             0.839973              0.278514
#
#     Degree of Financial Leverage (DFL)  \
# 0                             0.026601
# 1                             0.264577
# 2                             0.026555
# 3                             0.026697
# 4                             0.024752
#
#     Interest Coverage Ratio (Interest expense to EBIT)   Net Income Flag  \
# 0                                           0.564050                   1
# 1                                           0.570175                   1
# 2                                           0.563706                   1
# 3                                           0.564663                   1
# 4                                           0.575617                   1
#
#     Equity to Liability
# 0              0.016469
# 1              0.020794
# 2              0.016474
# 3              0.023982
# 4              0.035490
#
# [5 rows x 96 columns]

# %% [markdown]
# #### The dataset contains 96 columns, let’s have a look at the correlation before training the model:
#
# #### Veri kümesi 96 sütun içerir, modeli eğitmeden önce korelasyona bir göz atalım:

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### As the “Bankrupt?” column is the target label so I will drop it from the training data:
#
# #### “İflas mı?” sütun hedef etikettir, bu yüzden onu eğitim verilerinden çıkaracağım:

# %%
X=data.drop(["Bankrupt?"],axis="columns")
y=data["Bankrupt?"]

# %% [markdown]
# #### Now let’s split the dataset and use the logistic regression model to train the bankruptcy prediction model:
#
# #### Şimdi veri kümesini bölelim ve iflas tahmin modelini eğitmek için lojistik regresyon modelini kullanalım:

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
logreg = LogisticRegression()

# %%
logreg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# #### Now let’s have a look at the accuracy score on the training set:
#
# #### Şimdi eğitim setindeki doğruluk puanına bir göz atalım:

# %%
logreg.score(x_test,y_test)
# Out:
# 0.9655425219941349

# %% [markdown]
# # Conclusion
# #### So the model is performing well on the training data by giving an accuracy of about 95%. This is how we can use machine learning in finance. You can do a lot more on this dataset to explore more use cases of machine learning in finance. I hope you liked this article on how to train a bankruptcy prediction model with machine learning using Python. Feel free to ask your valuable questions in the comments section below.
#
# # Çözüm
# #### Yani model, yaklaşık %95 doğruluk vererek eğitim verileri üzerinde iyi performans gösteriyor. Finansta makine öğrenimini bu şekilde kullanabiliriz. Finansta makine öğreniminin daha fazla kullanım örneğini keşfetmek için bu veri kümesinde çok daha fazlasını yapabilirsiniz. Python kullanarak makine öğrenimi ile bir iflas tahmin modelinin nasıl eğitileceği hakkındaki bu makaleyi umarım beğenmişsinizdir. Değerli sorularınızı aşağıdaki yorumlar bölümünde sormaktan çekinmeyin.
